# %%
print("Hello Machine Learning!")
# Out:
# Hello Machine Learning!

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.5

# %%
import numpy as np
salary = np.array([3000,4000.45,5000.92])
print(salary)
# Out:
# [3000.   4000.45 5000.92]

# %%
marks = np.array([
    [80, 85, 90],   # Student 1
    [70, 75, 88],   # Student 2
    [60, 65, 70]    # Student 3
])
print(marks.shape)
# Out:
# (3, 3)

# %%
ratings = np.array([4,5,3,4])
print(ratings.ndim)
# Out:
# 1

# %%
print(marks.ndim)
# Out:
# 2

# %%
prices = np.array([100,200,300,400])
discount = prices * 0.9
print(discount)
# Out:
# [ 90. 180. 270. 360.]

# %%
salaries = np.array([125000.00,248000.45,184000.00])
new_salaries = salaries + 500
print(new_salaries)
# Out:
# [125500.   248500.45 184500.  ]

# %%
sales = np.array([
    [1000,1200,1500],
    [2000,2200,2500],
    [3000,3200,3500]
    ])
# Rows = employees 
# Columns = Months
bonus = np.array([100,200,300])
updated_sales = sales+bonus
print(updated_sales)
# Out:
# [[1100 1400 1800]
#  [2100 2400 2800]
#  [3100 3400 3800]]
