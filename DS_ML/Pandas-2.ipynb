# %%
# Loading data from CSV file

import pandas as pd

data = pd.read_csv("datasets/nba.csv")

print(data.head())
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
print(data.Salary)
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          NaN
# Name: Salary, Length: 458, dtype: float64

# %%
print(data.head(2))
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
#
#      College     Salary
# 0      Texas  7730337.0
# 1  Marquette  6796117.0

# %%
print(data.tail(2))
# Out:
#             Name       Team  Number Position   Age Height  Weight College  \
# 456  Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0  Kansas
# 457          NaN        NaN     NaN      NaN   NaN    NaN     NaN     NaN
#
#        Salary
# 456  947276.0
# 457       NaN

# %%
print(data.columns)
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='str')

# %%
import pandas as pd

col_names = ['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
       'College', 'Salary']

df = pd.DataFrame(col_names)

print(df)
# Out:
#           0
# 0      Name
# 1      Team
# 2    Number
# 3  Position
# 4       Age
# 5    Height
# 6    Weight
# 7   College
# 8    Salary

# %%
data = {
    'Name' : ['Ravi','Kumar','Krishna'],
    'salary': [125000.00,285000.00,197403.00]
}

df = pd.DataFrame(data)

print(df)
# Out:
#       Name    salary
# 0     Ravi  125000.0
# 1    Kumar  285000.0
# 2  Krishna  197403.0

# %%
import pandas as pd

df = pd.read_csv('datasets/nba.csv')

print(df[['Name','Salary']])
# Out:
#               Name     Salary
# 0    Avery Bradley  7730337.0
# 1      Jae Crowder  6796117.0
# 2     John Holland        NaN
# 3      R.J. Hunter  1148640.0
# 4    Jonas Jerebko  5000000.0
# ..             ...        ...
# 453   Shelvin Mack  2433333.0
# 454      Raul Neto   900000.0
# 455   Tibor Pleiss  2900000.0
# 456    Jeff Withey   947276.0
# 457            NaN        NaN
#
# [458 rows x 2 columns]

# %%
df = pd.read_csv('datasets/nba.csv')

a_record = df.loc[0]

print(a_record)
# Out:
# Name         Avery Bradley
# Team        Boston Celtics
# Number                 0.0
# Position                PG
# Age                   25.0
# Height                 6-2
# Weight               180.0
# College              Texas
# Salary           7730337.0
# Name: 0, dtype: object

# %%
# Reading csv data and chaingin the index col from default zero to Name

df = pd.read_csv('datasets/nba.csv',index_col="Name")

# print(df.head(2))

a_record = df.loc["Jae Crowder"]

print(a_record)
# Out:
# Team        Boston Celtics
# Number                99.0
# Position                SF
# Age                   25.0
# Height                 6-6
# Weight               235.0
# College          Marquette
# Salary           6796117.0
# Name: Jae Crowder, dtype: object

# %%
# using .iloc[]

row2 = df.iloc[3]

print(row2)
# Out:
# Team        Boston Celtics
# Number                28.0
# Position                SG
# Age                   22.0
# Height                 6-5
# Weight               185.0
# College      Georgia State
# Salary           1148640.0
# Name: R.J. Hunter, dtype: object

# %%
print(df.isnull())
# Out:
#                 Team  Number  Position    Age  Height  Weight  College  Salary
# Name
# Avery Bradley  False   False     False  False   False   False    False   False
# Jae Crowder    False   False     False  False   False   False    False   False
# John Holland   False   False     False  False   False   False    False    True
# R.J. Hunter    False   False     False  False   False   False    False   False
# Jonas Jerebko  False   False     False  False   False   False     True   False
# ...              ...     ...       ...    ...     ...     ...      ...     ...
# Shelvin Mack   False   False     False  False   False   False    False   False
# Raul Neto      False   False     False  False   False   False     True   False
# Tibor Pleiss   False   False     False  False   False   False     True   False
# Jeff Withey    False   False     False  False   False   False    False   False
# NaN             True    True      True   True    True    True     True    True
#
# ...

# %%
df = pd.DataFrame(pd.read_csv('datasets/nba.csv'))

print(df[['Name','Salary']].head(5))
# Out:
#             Name     Salary
# 0  Avery Bradley  7730337.0
# 1    Jae Crowder  6796117.0
# 2   John Holland        NaN
# 3    R.J. Hunter  1148640.0
# 4  Jonas Jerebko  5000000.0

# %%
five_records = df[['Name','Salary']].head(5)

print(five_records.fillna(0))
# Out:
#             Name     Salary
# 0  Avery Bradley  7730337.0
# 1    Jae Crowder  6796117.0
# 2   John Holland        0.0
# 3    R.J. Hunter  1148640.0
# 4  Jonas Jerebko  5000000.0

# %%
import numpy as np
print(five_records.replace(np.nan,0))
# Out:
#             Name     Salary
# 0  Avery Bradley  7730337.0
# 1    Jae Crowder  6796117.0
# 2   John Holland        0.0
# 3    R.J. Hunter  1148640.0
# 4  Jonas Jerebko  5000000.0

# %%
import pandas as pd
import numpy as np

data = pd.Series([10,np.nan,30,40,np.nan,60])

print(data)

print(data.interpolate())
# Out:
# 0    10.0
# 1     NaN
# 2    30.0
# 3    40.0
# 4     NaN
# 5    60.0
# dtype: float64
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4    50.0
# 5    60.0
# dtype: float64

# %%
df = pd.DataFrame(pd.read_csv('datasets/nba.csv'))

print(df[['Name','Salary']].head(5))
# Out:
#             Name     Salary
# 0  Avery Bradley  7730337.0
# 1    Jae Crowder  6796117.0
# 2   John Holland        NaN
# 3    R.J. Hunter  1148640.0
# 4  Jonas Jerebko  5000000.0

# %%
print(df[['Name','Salary']].head(5).dropna())
# Out:
#             Name     Salary
# 0  Avery Bradley  7730337.0
# 1    Jae Crowder  6796117.0
# 3    R.J. Hunter  1148640.0
# 4  Jonas Jerebko  5000000.0

# %%
nan_rows = df[df.isna().any(axis=1)]

print(nan_rows.head(5)) #showing only 5 records.
# Out:
#                 Name            Team  Number Position   Age Height  Weight  \
# 2       John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4      Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5       Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 15  Bojan Bogdanovic   Brooklyn Nets    44.0       SG  27.0    6-8   216.0
# 20    Sergey Karasev   Brooklyn Nets    10.0       SG  22.0    6-7   208.0
#
#               College      Salary
# 2   Boston University         NaN
# 4                 NaN   5000000.0
# 5                 NaN  12000000.0
# 15                NaN   3425510.0
# 20                NaN   1599840.0

# %%
nan_salary = df[df['Salary'].isna()]

print(nan_salary[['Name','Salary']])
# Out:
#                Name  Salary
# 2      John Holland     NaN
# 46      Elton Brand     NaN
# 171   Dahntay Jones     NaN
# 264   Jordan Farmar     NaN
# 269    Ray McCallum     NaN
# 270  Xavier Munford     NaN
# 273  Alex Stepheson     NaN
# 350   Briante Weber     NaN
# 353   Dorell Wright     NaN
# 397    Axel Toupane     NaN
# 409      Greg Smith     NaN
# 457             NaN     NaN

# %%
salary_age = df[df[['Salary','Age']].isna().any(axis=1)]

print(salary_age.head(5)) #Showing only 5 Records
# Out:
#               Name                 Team  Number Position   Age Height  Weight  \
# 2     John Holland       Boston Celtics    30.0       SG  27.0    6-5   205.0
# 46     Elton Brand   Philadelphia 76ers    42.0       PF  37.0    6-9   254.0
# 171  Dahntay Jones  Cleveland Cavaliers    30.0       SG  35.0    6-6   225.0
# 264  Jordan Farmar    Memphis Grizzlies     4.0       PG  29.0    6-2   180.0
# 269   Ray McCallum    Memphis Grizzlies     5.0       PG  24.0    6-3   190.0
#
#                College  Salary
# 2    Boston University     NaN
# 46                Duke     NaN
# 171               Duke     NaN
# 264               UCLA     NaN
# 269            Detroit     NaN

# %%
df = pd.DataFrame(pd.read_csv('datasets/nba.csv'))

print(df.isna().sum())
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df = pd.DataFrame(pd.read_csv('datasets/nba.csv'))

print(df[['Salary']].isna().sum())
# Out:
# Salary    12
# dtype: int64

# %%
print(df[['College']].isna().sum())
# Out:
# College    85
# dtype: int64

# %%
print(df[['College','Salary']].isna().sum())
# Out:
# College    85
# Salary     12
# dtype: int64

# %%
print(df[df.isna()])
# Out:
#     Name Team  Number Position  Age Height  Weight College  Salary
# 0    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 1    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 2    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 3    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 4    NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# ..   ...  ...     ...      ...  ...    ...     ...     ...     ...
# 453  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 454  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 455  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 456  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 457  NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
#
# [458 rows x 9 columns]
